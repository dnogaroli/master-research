# %% [markdown]
# In this notebook, we used Dynamics Topic Modeling to explore how terms used in speeches have changed over time.

# %%
import pandas as pd
import numpy as np

import pickle
import logging

import ast
import gensim
from gensim.models import Phrases, LdaModel, LdaSeqModel
from gensim.corpora import Dictionary
from gensim.models.coherencemodel import CoherenceModel

import plotly.express as px
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("amazon_clean_discourses.tsv", sep="\t", encoding="utf-8")
df = df.drop(["discourse_link", "session", "original_discourse", "phase", "speaker", "party", "state"], axis=1)

# create a year colunm
df['year'] = pd.DatetimeIndex(df['date']).year

# set date as index
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df = df.set_index(['date'], drop=False)

# tokenizing column
df["tokenized"] = [gensim.utils.simple_preprocess(line) for line in df["tokenized"]]

# %%
# building bigram
bigram = gensim.models.Phrases(df["tokenized"], min_count=5, threshold=90)
bigram_mod = gensim.models.phrases.Phraser(bigram)

def make_bigrams(text):
    return [bigram_mod[doc] for doc in text]

# adding a column in our df
df["bigrams"] = make_bigrams(df["tokenized"])

# now, we get all the discourses and convert them to a list of strings.
# the output is a list containing list of strings for each document (discourse)
bigrams = df['bigrams'].values

# %% [markdown]
# A very important input for DTM to work is the time_slice input. It should be a list which contains the number of documents in each time slice. In our case, the time slice will be in years.

# %%
time_stamps = np.arange(int(df.year.min(axis=0)), int(df.year.max(axis=0))+1, 1)
time_stamps = list(time_stamps)

# find out the time slice
gp = df.groupby(by=['year'])
total_yearly_list = list(gp.size())

time_slice = total_yearly_list
print(time_slice)
# Out:
# [164, 797, 337, 1070, 898, 874, 575, 1180, 1188, 1342, 483, 726, 568, 700, 404, 438, 273, 641, 298, 859, 296, 491]

# %%
# dictionary: tokens will be translated to unique ids, we may do this by transforming the text to a list of words and passing it to the method
dictionary = Dictionary(bigrams)

# no_above: keep tokens which are contained in no more than X% documents, this means that tokens appearing in more than 60% will be removed
# no_below: keep tokens which are contained in at least Y documents; less than 5 documents
# so we'll filter out words that occur less than 5 documents, or more than 20% of the documents.
dictionary.filter_extremes(no_above=0.6, no_below=5)
# print(dictionary.token2id)

# the corpus object contains both the word id and the frequency with which it appears in each doc. 
# to create a BOW corpus, we need to feed the tokenized list of words to the dictionary after it has been updated
texts = bigrams
corpus = [dictionary.doc2bow(text) for text in texts]
#pickle.dump(corpus, open('corpus.pkl', 'wb'))

# dictionary = pickle.load(open('amazon_dictionary.pkl', 'rb'))
# corpus = pickle.load(open('corpus.pkl', 'rb'))

print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(corpus))
# Out:
# Number of unique tokens: 50454
# Number of documents: 14602

# %%
logging.basicConfig(format='%(levelname)s : %(message)s', level=logging.INFO)
logging.root.level = logging.INFO

# use LdaSeqModel to generate DTM results
ldaseq = LdaSeqModel(corpus=corpus, id2word=dictionary, time_slice=time_slice, num_topics=12,
                    lda_model=lda_model, passes=1, lda_inference_max_iter=8, em_min_iter=4,
                    em_max_iter=6, chunksize=30)
# Out:
# INFO : using symmetric eta at 0.08333333333333333
# INFO : using serial LDA version on this node
# INFO : running online (single-pass) LDA training, 12 topics, 1 passes over the supplied corpus of 14602 documents, updating model once every 2000 documents, evaluating perplexity every 14602 documents, iterating 50x with a convergence threshold of 0.001000
# WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# INFO : topic #5 (0.010): 0.010*"desenvolvimento" + 0.008*"região" + 0.006*"obras" + 0.006*"nacional" + 0.006*"pará" + 0.005*"federal" + 0.005*"investimentos" + 0.005*"mato_grosso" + 0.005*"energia" + 0.005*"recursos"
# INFO : topic diff=0.598425, rho=0.377964
# INFO : -9.333 per-word bound, 644.8 perplexity estimate based on a held-out corpus of 602 documents with 89641 words
# INFO : PROGRESS: pass 0, at document #14602/14602
# INFO : merging changes from 602 documents into a model of 14602 documents
# INFO : topic #1 (0.010): 0.012*"lei" + 0.008*"bolsonaro" + 0.008*"medida_provisória" + 0.007*"projeto" + 0.007*"nacional" + 0.006*"trabalho" + 0.005*"trabalhadores" + 0.004*"federal" + 0.004*"defesa" + 0.004*"emendas"
# INFO : topic #0 (0.010): 0.012*"federal" + 0.012*"amazonas" + 0.010*"região" + 0.008*"manaus" + 0.007*"projeto" + 0.005*"recursos" + 0.005*"nacional" + 0.005*"zona_franca" + 0.005*"ministério" + 0.004*"pará"
# INFO : topic #4 (0.010): 0.028*"água" + 0.017*"rio" + 0.011*"francisco" + 0.006*"projeto" + 0.006*"nordeste" + 0.006*"população" + 0.005*"região" + 0.005*"seca" + 0.005*"nacional" + 0.004*"integração"
# INFO : topic #6 (0.010): 0.010*"produção" + 0.007*"água" + 0.006*"mundo" + 0.005*"países" + 0.005*"rio" + 0.004*"energia" + 0.004*"economia" + 0.004*"agricultura" + 0.004*"alimentos" + 0.003*"mundial"
# INFO : topic #8 (0.010): 0.006*"nordeste" + 0.005*"lula" + 0.005*"dilma" + 0.005*"dinheiro" + 0.004*"federal" + 0.004*"população" + 0.004*"reais" + 0.004*"partido" + 0.004*"nacional" + 0.004*"roraima"
# INFO : topic diff=0.493862, rho=0.353553
# INFO :  EM iter 0
# INFO : E Step
# INFO : using symmetric eta at 0.08333333333333333
# INFO : using serial LDA version on this node
# INFO : M Step
# INFO : Fitting topic number 0
# INFO : Computing bound, all times
# INFO : initial sslm bound is -4036498.130926
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -3925553.792012 convergence is 0.027485
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -3896153.314030 convergence is 0.007490
# INFO : Fitting topic number 1
# INFO : Computing bound, all times
# INFO : initial sslm bound is -2832044.238256
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -2757811.689859 convergence is 0.026212
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -2738453.745126 convergence is 0.007019
# INFO : Fitting topic number 2
# INFO : Computing bound, all times
# INFO : initial sslm bound is -3430765.456033
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -3343547.377125 convergence is 0.025422
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -3319673.750431 convergence is 0.007140
# INFO : Fitting topic number 3
# INFO : Computing bound, all times
# INFO : initial sslm bound is -1498542.527385
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -1454266.384285 convergence is 0.029546
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -1445002.514078 convergence is 0.006370
# INFO : Fitting topic number 4
# INFO : Computing bound, all times
# INFO : initial sslm bound is -2224395.793792
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -2148633.737381 convergence is 0.034060
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -2129114.493692 convergence is 0.009084
# INFO : Fitting topic number 5
# INFO : Computing bound, all times
# INFO : initial sslm bound is -4217597.650862
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -4111765.554219 convergence is 0.025093
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -4082012.193467 convergence is 0.007236
# INFO : Fitting topic number 6
# INFO : Computing bound, all times
# INFO : initial sslm bound is -3692459.351443
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -3595837.176866 convergence is 0.026167
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -3569700.202539 convergence is 0.007269
# INFO : Fitting topic number 7
# INFO : Computing bound, all times
# INFO : initial sslm bound is -3680117.708467
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -3588662.615778 convergence is 0.024851
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -3565980.607820 convergence is 0.006320
# INFO : Fitting topic number 8
# INFO : Computing bound, all times
# INFO : initial sslm bound is -3295137.698245
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -3206143.264071 convergence is 0.027008
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -3184365.838633 convergence is 0.006792
# INFO : Fitting topic number 9
# INFO : Computing bound, all times
# INFO : initial sslm bound is -2529902.712752
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -2464768.915303 convergence is 0.025746
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -2448460.944640 convergence is 0.006616
# INFO : Fitting topic number 10
# INFO : Computing bound, all times
# INFO : initial sslm bound is -2624541.622451
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -2556472.953050 convergence is 0.025935
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -2538618.123657 convergence is 0.006984
# INFO : Fitting topic number 11
# INFO : Computing bound, all times
# INFO : initial sslm bound is -4923697.493648
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -4795248.408936 convergence is 0.026088
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -4760285.610738 convergence is 0.007291
# INFO : Bound went down, increasing iterations to 16
# C:\Users\dnogaroli\AppData\Roaming\Python\Python38\site-packages\gensim\models\ldaseqmodel.py:293: RuntimeWarning: divide by zero encountered in double_scalars
#   convergence = np.fabs((bound - old_bound) / old_bound)
# INFO : iteration 0 iteration lda seq bound is -83370410.249787 convergence is inf
# INFO :  EM iter 1
# INFO : E Step
# INFO : using symmetric eta at 0.08333333333333333
# INFO : using serial LDA version on this node
# INFO : M Step
# INFO : Fitting topic number 0
# INFO : Computing bound, all times
# INFO : initial sslm bound is -3365413.627114
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -3345068.607288 convergence is 0.006045
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -3335285.596959 convergence is 0.002925
# INFO : Fitting topic number 1
# INFO : Computing bound, all times
# INFO : initial sslm bound is -2823735.956953
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -2806787.050822 convergence is 0.006002
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -2799579.525286 convergence is 0.002568
# INFO : Fitting topic number 2
# INFO : Computing bound, all times
# INFO : initial sslm bound is -3366638.854829
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -3348076.981868 convergence is 0.005513
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -3339423.389987 convergence is 0.002585
# INFO : Fitting topic number 3
# INFO : Computing bound, all times
# INFO : initial sslm bound is -1443779.800730
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -1432872.307985 convergence is 0.007555
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -1429173.248179 convergence is 0.002582
# INFO : Fitting topic number 4
# INFO : Computing bound, all times
# INFO : initial sslm bound is -1875215.530560
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -1859657.813165 convergence is 0.008296
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -1853230.714110 convergence is 0.003456
# INFO : Fitting topic number 5
# INFO : Computing bound, all times
# INFO : initial sslm bound is -3615257.481036
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -3595269.230727 convergence is 0.005529
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -3585495.997808 convergence is 0.002718
# INFO : Fitting topic number 6
# INFO : Computing bound, all times
# INFO : initial sslm bound is -3664396.889790
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -3645643.120402 convergence is 0.005118
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -3636230.109166 convergence is 0.002582
# INFO : Fitting topic number 7
# INFO : Computing bound, all times
# INFO : initial sslm bound is -3791489.542107
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -3774901.945213 convergence is 0.004375
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -3767145.688101 convergence is 0.002055
# INFO : Fitting topic number 8
# INFO : Computing bound, all times
# INFO : initial sslm bound is -3793868.441998
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -3775688.560436 convergence is 0.004792
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -3767434.827890 convergence is 0.002186
# INFO : Fitting topic number 9
# INFO : Computing bound, all times
# INFO : initial sslm bound is -2449413.043625
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -2436898.149835 convergence is 0.005109
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -2431313.874982 convergence is 0.002292
# INFO : Fitting topic number 10
# INFO : Computing bound, all times
# INFO : initial sslm bound is -2477324.656663
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -2463259.169222 convergence is 0.005678
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -2457197.164377 convergence is 0.002461
# INFO : Fitting topic number 11
# INFO : Computing bound, all times
# INFO : initial sslm bound is -4654961.605842
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -4631234.066033 convergence is 0.005097
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -4619064.761850 convergence is 0.002628
# INFO : iteration 1 iteration lda seq bound is -80871604.153635 convergence is 0.029972
# INFO :  EM iter 2
# INFO : E Step
# INFO : using symmetric eta at 0.08333333333333333
# INFO : using serial LDA version on this node
# INFO : M Step
# INFO : Fitting topic number 0
# INFO : Computing bound, all times
# INFO : initial sslm bound is -3091897.927598
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -3083765.812376 convergence is 0.002630
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -3079493.552810 convergence is 0.001385
# INFO : Fitting topic number 1
# INFO : Computing bound, all times
# INFO : initial sslm bound is -2841449.437967
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -2833940.034058 convergence is 0.002643
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -2830540.373921 convergence is 0.001200
# INFO : Fitting topic number 2
# INFO : Computing bound, all times
# INFO : initial sslm bound is -3389151.926951
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -3381167.333653 convergence is 0.002356
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -3377041.648987 convergence is 0.001220
# INFO : Fitting topic number 3
# INFO : Computing bound, all times
# INFO : initial sslm bound is -1601007.639976
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -1595696.721718 convergence is 0.003317
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -2454996.512451 convergence is 0.000593
# INFO : Fitting topic number 11
# INFO : Computing bound, all times
# INFO : initial sslm bound is -4484670.606542
# INFO : Computing bound, all times
# INFO : iteration 1 iteration lda seq bound is -4479559.437396 convergence is 0.001140
# INFO : Computing bound, all times
# INFO : iteration 2 iteration lda seq bound is -4476465.740117 convergence is 0.000691
# INFO : iteration 3 iteration lda seq bound is -79708426.206319 convergence is 0.005110
# INFO :  EM iter 4
# INFO : E Step
# INFO : using symmetric eta at 0.08333333333333333
# INFO : using serial LDA version on this node
# INFO : M Step
# INFO : Fitting topic number 0
# INFO : Computing bound, all times
# INFO : initial sslm bound is -2837668.234384

# %%
# save ldaseq model
# ldaseq.save("dtm_model")

# load
ldaseq = LdaSeqModel.load("dtm_amazon")

# %% [markdown]
# Let's find the coherence values for the DTM: we have to specify the time-slice we want to find coherence for.

# %%
# we just have to specify the time-slice we want to find coherence for.
topics_dtm = ldaseq.dtm_coherence(time=1)

cmass_DTM = CoherenceModel(topics=topics_dtm, corpus=corpus, dictionary=dictionary, coherence='u_mass')
print("DTM u_mass:", cmass_DTM.get_coherence())

ccv_DTM = CoherenceModel(topics=topics_dtm, texts=texts, dictionary=dictionary, coherence='c_v')
print("DTM ccv_mass:", ccv_DTM.get_coherence())
# Out:
# DTM u_mass: -1.3532025923197004
# DTM ccv_mass: 0.4527922597570973

# %%
def topic_time(topic, time_stamps):
    '''function that gets a particular topic's terms and stores in a dataframe where
    columns are the time slices'''
    for i in range(len(time_slice)-1):
        if i==0:
            temp_1 = pd.DataFrame(topic[i])
            temp_2 = pd.DataFrame(topic[i+1])
            temp_1.columns = ['words', time_stamps[i]]
            temp_2.columns = ['words', time_stamps[i+1]]
            temp_1 = pd.merge(temp_1,temp_2)
        else:
            temp_2 = pd.DataFrame(topic[i+1])
            temp_2.columns = ['words', time_stamps[i+1]]
            temp_1 = pd.merge(temp_1,temp_2)
    topic_words_time=temp_1
    
    return topic_words_time

# %%
DTM0 = ldaseq.print_topic_times(topic=0, top_terms=500)
DTM2 = ldaseq.print_topic_times(topic=2, top_terms=500)
DTM3 = ldaseq.print_topic_times(topic=3, top_terms=500)
DTM4 = ldaseq.print_topic_times(topic=4, top_terms=500)
DTM5 = ldaseq.print_topic_times(topic=5, top_terms=500)
DTM6 = ldaseq.print_topic_times(topic=6, top_terms=500)
DTM7 = ldaseq.print_topic_times(topic=7, top_terms=500)
DTM9 = ldaseq.print_topic_times(topic=9, top_terms=500)
DTM10 = ldaseq.print_topic_times(topic=10, top_terms=500)
DTM11 = ldaseq.print_topic_times(topic=11, top_terms=500)

# %%
# apply the function and save as csv
# economical development
topic0 = topic_time(DTM0, time_stamps)
topic0.to_csv("dtm_topic0.csv", sep=",")

# social welfare
topic2 = topic_time(DTM2, time_stamps)
topic2.to_csv("dtm_topic2.csv", sep=",")

# foreign affairs
topic3 = topic_time(DTM3, time_stamps)
topic3.to_csv("dtm_topic3.csv", sep=",")

# water transposition
topic4 = topic_time(DTM4, time_stamps)
topic4.to_csv("dtm_topic4.csv", sep=",")

# road projects
topic5 = topic_time(DTM5, time_stamps)
topic5.to_csv("dtm_topic5.csv", sep=",")

# agricultural expansion
topic6 = topic_time(DTM6, time_stamps)
topic6.to_csv("dtm_topic6.csv", sep=",")

# indigenous rights
topic7 = topic_time(DTM7, time_stamps)
topic7.to_csv("dtm_topic7.csv", sep=",")

# national sovereignty
topic9 = topic_time(DTM9, time_stamps)
topic9.to_csv("dtm_topic9.csv", sep=",")

# land rights
topic10 = topic_time(DTM10, time_stamps)
topic10.to_csv("dtm_topic10.csv", sep=",")

# environmental protection
topic11 = topic_time(DTM11, time_stamps)
topic11.to_csv("dtm_topic11.csv", sep=",")

# %%
rows0 = ['recursos', 'desenvolvimento', 'zona_franca', 'empresas', 
         'suframa', 'dnit', 'sudam', 'incentivos_fiscais',
         'rondônia', 'regional']

df0 = topic0.loc[topic0['words'].isin(rows0)]
df0 = pd.melt(df0, id_vars=["words"], var_name="year")

ec = px.line(df0,
              x="year",
              y="value",
              color='words',
              color_discrete_sequence=px.colors.qualitative.Prism,
              labels={"words":"", "value":"probability"},
              width=900, 
              height=700,
              #groupnorm='percent',
              title="Amazon's Development topic selected terms probability over time")

newnames = {"recursos":"resources", "zona_franca":"MFTZ", "rondônia":"rondônia", "regional":"regional",
            "desenvolvimento":"development", "empresas":"companies", "sudam":"sudam",
            "incentivos_fiscais":"tax benefits", "suframa":"suframa", "dnit":"dnit"}

ec.for_each_trace(lambda t: t.update(name = newnames[t.name],
                                     legendgroup = newnames[t.name],
                                     hovertemplate = t.hovertemplate.replace(t.name, newnames[t.name])
                                    ))

ec.update_layout(
    xaxis = dict(
        tickmode = 'array',
        tickvals = [2000, 2005, 2010, 2015, 2020]))

ec.write_html("/dtm_economic_development.html")
ec.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="185cd204-d0dc-4ab0-8a01-81d20e785271" class="plotly-graph-div" style="height:700px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("185cd204-d0dc-4ab0-8a01-81d20e785271")) {                    Plotly.newPlot(                        "185cd204-d0dc-4ab0-8a01-81d20e785271",                        [{"hovertemplate":"=resources<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"resources","line":{"color":"rgb(95, 70, 144)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"resources","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0110955170440256,0.0115159924563046,0.011094571502745,0.0115939372137359,0.0113655990275528,0.0121067921398059,0.0105686135404329,0.009689808652186,0.0088710632968135,0.0088393958585015,0.0074401897363662,0.0058312540843974,0.0044664602194449,0.0037023432176039,0.0035211257959568,0.0036020184568446,0.0036932786433475,0.0037847587837137,0.0039442749573772,0.0041276421885794,0.0043400983689771,0.0045040311271562],"yaxis":"y","type":"scatter"},{"hovertemplate":"=sudam<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"sudam","line":{"color":"rgb(29, 105, 150)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"sudam","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0109425590541043,0.0112101745416826,0.0075896983945445,0.0053804244372089,0.0033966566946878,0.0023110727092249,0.0018030036059907,0.0014428022419461,0.0011130696835806,0.0008776476567449,0.0007675049688075,0.0006978569079856,0.0006343767362298,0.0005857444778438,0.0005643732198891,0.0005631965353923,0.0005585284780514,0.0005474306031828,0.0005281339566121,0.0005024870840633,0.0004918603441865,0.0004852333519818],"yaxis":"y","type":"scatter"},{"hovertemplate":"=development<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"development","line":{"color":"rgb(56, 166, 165)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"development","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0104212940942389,0.0101143286897565,0.0103398010367672,0.0104052327811685,0.0096478708648611,0.0075500966726157,0.0073625546301003,0.0071903849806298,0.0056594750799266,0.004703631272363,0.0044731459473698,0.0042892288589577,0.0042777711970014,0.0044580551605924,0.004659077851832,0.0050415120587226,0.0054761313840088,0.0059160923714922,0.0065443237292678,0.0072967390452202,0.0071546210392243,0.0070287380646711],"yaxis":"y","type":"scatter"},{"hovertemplate":"=MFTZ<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"MFTZ","line":{"color":"rgb(15, 133, 84)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"MFTZ","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0083957532272598,0.006762983483708,0.0102419564881704,0.0085623518810841,0.0094847433243152,0.0068794966809189,0.008064514188931,0.0077121021727064,0.0071378892456722,0.0058713268297822,0.0067478689416343,0.008295074174417,0.0087603073899455,0.0096129268376988,0.0088856734297625,0.0074802948676222,0.0074533511234014,0.0084891916647752,0.0104972713694762,0.0133270853470771,0.0126338387863638,0.011853 ...

# %%
# topic 2: social welfare
rows2 = ['educação', 'saúde', 'recursos', 'trabalho', 'desenvolvimento', 
         'federal', 'sociais', 'jovens', 'políticas', 'direito']
         
df2 = topic2.loc[topic2['words'].isin(rows2)]
df2 = pd.melt(df2, id_vars=["words"], var_name="year")

sw = px.line(df2,
             x="year",
             y="value",
             color='words',
             color_discrete_sequence=px.colors.qualitative.Prism,
             labels={"words":"", "value":"probability"},
             width=900, 
             height=700,
             #groupnorm="percent",
             title="Social Welfare topic selected terms probability over time")

newnames = {"educação":"education", "saúde":"healthcare", "sociais":"social",
            "recursos":"resources", "trabalho":"labour", "desenvolvimento":"development",
            "direito":"rights", "jovens":"youth", "federal":"federal", "políticas":"policies"}

sw.for_each_trace(lambda t: t.update(name = newnames[t.name],
                                     legendgroup = newnames[t.name],
                                     hovertemplate = t.hovertemplate.replace(t.name, newnames[t.name])
                                    ))

sw.update_layout(
    xaxis = dict(
        tickmode = 'array',
        tickvals = [2000, 2005, 2010, 2015, 2020]))

sw.write_html("/dtm_social_welfare.html")
sw.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f5513feb-edd4-4d8e-b524-629601c1da1d" class="plotly-graph-div" style="height:700px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5513feb-edd4-4d8e-b524-629601c1da1d")) {                    Plotly.newPlot(                        "f5513feb-edd4-4d8e-b524-629601c1da1d",                        [{"hovertemplate":"=education<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"education","line":{"color":"rgb(95, 70, 144)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"education","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.013116411409353,0.013153593437057,0.0118471397717013,0.0127068523596022,0.0139869109486633,0.0173186876797989,0.0151858560745619,0.0139036324896386,0.0142076024752517,0.0152526695270896,0.0137824507443841,0.0150109107836093,0.0150278146331174,0.0181785782416906,0.0155062213769323,0.0162160531956282,0.0169065421447165,0.0196666779499091,0.020849501101035,0.0249114491368585,0.0286352333262902,0.0302490109872389],"yaxis":"y","type":"scatter"},{"hovertemplate":"=healthcare<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"healthcare","line":{"color":"rgb(29, 105, 150)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"healthcare","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0084224886275928,0.0082753364034825,0.0077965186627147,0.0063774166096002,0.0062775465529244,0.0065429419155685,0.0064577550470681,0.0066046751447035,0.0061989115606982,0.0059535919021858,0.0060496884416873,0.0067740957835703,0.0070351287697391,0.0093149058298969,0.0112651669514659,0.0146480306805188,0.012422334694921,0.0095071453541103,0.0086423273124275,0.0083456235212873,0.0085452585717643,0.0083299089204243],"yaxis":"y","type":"scatter"},{"hovertemplate":"=development<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"development","line":{"color":"rgb(56, 166, 165)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"development","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.007377656042043,0.0074272109394623,0.0075756547218946,0.0076577432493119,0.0072509408830269,0.0070839783110309,0.0075271155444672,0.0077969510526691,0.0077310700153476,0.0074377372595812,0.00731630123552,0.0070715358188064,0.0072267233551772,0.0073561116397191,0.0077320163375468,0.0073677320240124,0.0072345523255677,0.0071824440397108,0.0068037199597846,0.0061884314193493,0.0058082269586135,0.0056696711071439],"yaxis":"y","type":"scatter"},{"hovertemplate":"=resources<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"resources","line":{"color":"rgb(15, 133, 84)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"resources","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0072732101469774,0.0072155300277652,0.0061932512581166,0.0052729396337695,0.004974115409327,0.0043919432702064,0.0036333573668676,0.003142362217638,0.0029814106411343,0.0029698941985675,0.0032174129530274,0.0033068722873603,0.0033620343066307,0.0034927665355365,0.0036165054934697,0.0041212382322041,0.0043737984459327,0.0046132724849053,0.0052139976245414,0.0064385929297564 ...

# %%
# topic 3: foreign affairs
rows3 = ['mundo', 'países', 'internacional', 'desenvolvimento', 'mercosul',
         'relações_exteriores', 'economia', 'europa', 'américa_sul', 'venezuela']

df3 = topic3.loc[topic3['words'].isin(rows3)]
df3 = pd.melt(df3, id_vars=["words"], var_name="year")

fa = px.line(df3,
              x="year",
              y="value",
              color='words',
              color_discrete_sequence=px.colors.qualitative.Prism,
              labels={"words":"", "value":"probability"},
              width=900, 
              height=700,
              #groupnorm='percent',
              title="Foreign Affairs topic selected terms probability over time"
            )

newnames = {'mundo':'world', 'países':'countries', 'internacional':'international',
            'desenvolvimento':'development', 'mercosul':'mercosul','relações_exteriores':'foreign affairs', 
            'economia':'economic', 'europa':'europe', 'américa_sul':'south america', 'venezuela':'venezuela'
           }

fa.for_each_trace(lambda t: t.update(name = newnames[t.name],
                                     legendgroup = newnames[t.name],
                                     hovertemplate = t.hovertemplate.replace(t.name, newnames[t.name])))

fa.update_layout(
    xaxis = dict(
        tickmode = 'array',
        tickvals = [2000, 2005, 2010, 2015, 2020]))

fa.write_html("/dtm_foreign_affairs.html")
fa.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="27c4aff7-f6aa-4b1b-803c-15e214569de9" class="plotly-graph-div" style="height:700px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27c4aff7-f6aa-4b1b-803c-15e214569de9")) {                    Plotly.newPlot(                        "27c4aff7-f6aa-4b1b-803c-15e214569de9",                        [{"hovertemplate":"=world<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"world","line":{"color":"rgb(95, 70, 144)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"world","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0028484093608159,0.002824229859344,0.002950141604338,0.0030815770260836,0.0033586560729847,0.0036921045592777,0.0042785901044047,0.005017554562356,0.0053082879274362,0.005968249241788,0.0056768412724549,0.0053901911517272,0.0049768326105131,0.0045790157889141,0.0041390343561311,0.0038997188427726,0.0036666819824908,0.0035320475204824,0.0035103818306791,0.0036122554959004,0.0036656750276604,0.0037304652286747],"yaxis":"y","type":"scatter"},{"hovertemplate":"=countries<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"countries","line":{"color":"rgb(29, 105, 150)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"countries","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0027390879528216,0.0026470970688407,0.0025291185717458,0.0025146292398343,0.0025248211625188,0.0024131379426994,0.0023126129432239,0.00220293319857,0.0022175635692532,0.0022103014013346,0.002155950208654,0.0020857170049359,0.0021011841051451,0.0019761244516222,0.001840792223954,0.0017582542502013,0.0016990890435728,0.0016651513669287,0.0016562724266311,0.0016602117234715,0.0016424199353598,0.0016363670904437],"yaxis":"y","type":"scatter"},{"hovertemplate":"=development<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"development","line":{"color":"rgb(56, 166, 165)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"development","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0024496134471453,0.0024793462377627,0.0025406333040632,0.0026524648955051,0.0027244843549775,0.0027316516976418,0.0026841593237521,0.0026281658602693,0.0025589956722782,0.0024357830796067,0.0023807833454797,0.0023329485468612,0.0022508476101104,0.0021912637050303,0.0021514674663587,0.0021328451669218,0.002101528839816,0.0020964891638418,0.002071850095118,0.0020501432171175,0.0020278573940321,0.0020161573169731],"yaxis":"y","type":"scatter"},{"hovertemplate":"=venezuela<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"venezuela","line":{"color":"rgb(15, 133, 84)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"venezuela","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0014222675779801,0.0014354344843309,0.0013861172704885,0.0013681769813171,0.0013808391359739,0.0014767247644218,0.0016565998273939,0.0018928941856624,0.0019305816575005,0.0019352217103974,0.0018265537408688,0.0017057693596719,0.0016873138156071,0.0016552947767799,0.0016070931862148,0.0014733814946248,0.0013822110252804,0.00132481432249,0.0012970807659676,0.0012829223544789,0.001262632581443 ...

# %%
# topic 4: water transposition
rows4 = ['rio', 'francisco', 'recursos_hídricos', 'transposição', 'seca', 
         'integração', 'sustentável', 'saneamento', 'semi_árido', 'projeto', 
         'desenvolvimento']

df4 = topic4.loc[topic4['words'].isin(rows4)]
df4 = pd.melt(df4, id_vars=["words"], var_name="year")

wt = px.line(df4,
              x="year",
              y="value",
              color='words',
              color_discrete_sequence=px.colors.qualitative.Prism,
              labels={"words":"", "value":"probability"},
              width=900, 
              height=700,
              #groupnorm='percent',
              title="Water Transposition topic selected terms probability over time")

newnames = {"rio":"river", "francisco":"francisco", "seca":"dry",
            "recursos_hídricos":"water resources", "sustentável":"sustainable", 
            "saneamento":"sanitation", "semi_árido":"semiarid", "projeto":"project",
            "desenvolvimento":"development", "transposição":"transposition",
            "integração":"integration"}

wt.for_each_trace(lambda t: t.update(name = newnames[t.name],
                                     legendgroup = newnames[t.name],
                                     hovertemplate = t.hovertemplate.replace(t.name, newnames[t.name])
                                    ))

wt.update_layout(
    xaxis = dict(
        tickmode = 'array',
        tickvals = [2000, 2005, 2010, 2015, 2020]))

wt.write_html("/dtm_water_transposition.html")
wt.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4a8e6a1e-e280-4a43-a479-edd517537777" class="plotly-graph-div" style="height:700px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a8e6a1e-e280-4a43-a479-edd517537777")) {                    Plotly.newPlot(                        "4a8e6a1e-e280-4a43-a479-edd517537777",                        [{"hovertemplate":"=river<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"river","line":{"color":"rgb(95, 70, 144)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"river","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0228222177690336,0.0236823864930372,0.0218811786087787,0.0215052209477825,0.0189371147987348,0.0214594365813928,0.0226449582033686,0.0223780184273064,0.0219383554782967,0.0183250423698008,0.0156868914915351,0.0165161217357916,0.0165953659454634,0.0170613849805993,0.02858762554076,0.0331252148925076,0.0315316214279298,0.0364859587207753,0.0366944309900845,0.0334468691134862,0.0359463667104184,0.0370091391595629],"yaxis":"y","type":"scatter"},{"hovertemplate":"=project<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"project","line":{"color":"rgb(29, 105, 150)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"project","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0223539522487853,0.0225324714452065,0.0137497138360334,0.0100924207790832,0.0079976280597471,0.0069366174823522,0.0057849749873728,0.0049677736424891,0.0044668442781831,0.0042880162330688,0.0045506944096735,0.0050247984500053,0.005334167041419,0.0062630960595698,0.0079812522967015,0.0093966332990873,0.0081974891778299,0.007334012239136,0.0067878170954419,0.0065256541644996,0.0066034995272667,0.0065759835444345],"yaxis":"y","type":"scatter"},{"hovertemplate":"=francisco<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"francisco","line":{"color":"rgb(56, 166, 165)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"francisco","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0167568592605212,0.0171422495845704,0.0138082260750424,0.0130744168663928,0.0114065217460936,0.0132916429720485,0.0128940844971066,0.0131038488966913,0.0121154327281984,0.0094864074791263,0.0095760993200538,0.0107708581296754,0.0093543403390349,0.0106373353684682,0.0153092510482802,0.020267299887831,0.0169421789438246,0.0158686689873361,0.0126524760956831,0.0114526330185418,0.0112955259224645,0.0111415625647173],"yaxis":"y","type":"scatter"},{"hovertemplate":"=dry<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"dry","line":{"color":"rgb(15, 133, 84)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"dry","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0068049318516976,0.0067004112611239,0.0065477084522285,0.0060271819003081,0.0058233952725691,0.0070578892798636,0.0063661345874897,0.0055050854073299,0.005288081025712,0.0056070639859983,0.0061649488120006,0.0074692500036984,0.011049452741659,0.0109747566164187,0.0082698514870085,0.0070199467733972,0.0079305311295835,0.0071868817813767,0.0067179250026123,0.0064564447783413,0.0064872403876659,0.006489089651501],"yax ...

# %%
# topic 5: road projects
rows5 = ["investimentos", "infraestrutura", "construção",
         "recursos", "obras", "transportes", "aeroportos", "privatização",
         "turismo"]

df5 = topic5.loc[topic5['words'].isin(rows5)]
df5 = pd.melt(df5, id_vars=["words"], var_name="year")

rp = px.line(df5,
              x="year",
              y="value",
              color='words',
              color_discrete_sequence=px.colors.qualitative.Prism,
              labels={"words":"", "value":"probability"},
              width=900, 
              height=700,
              #groupnorm='percent',
              title="Road Projects topic selected terms probability over time")

newnames = {"investimentos":"investments", "infraestrutura":"infrastructure", 
           "construção":"construction", "recursos":"recourses", "obras":"works",
           "transportes":"transport", "aeroportos":"airports", "privatização":"privatization",
           "turismo":"tourism"}

rp.for_each_trace(lambda t: t.update(name = newnames[t.name],
                                     legendgroup = newnames[t.name],
                                     hovertemplate = t.hovertemplate.replace(t.name, newnames[t.name])
                                    ))

rp.update_layout(
    xaxis = dict(
        tickmode = 'array',
        tickvals = [2000, 2005, 2010, 2015, 2020]))


rp.write_html("/dtm_road_projects.html")
rp.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2deae855-f81a-473e-865d-430ef50e914a" class="plotly-graph-div" style="height:700px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2deae855-f81a-473e-865d-430ef50e914a")) {                    Plotly.newPlot(                        "2deae855-f81a-473e-865d-430ef50e914a",                        [{"hovertemplate":"=investments<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"investments","line":{"color":"rgb(95, 70, 144)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"investments","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0067802330678269,0.0066505615340919,0.0063697325824831,0.0063043872287598,0.0065994431745238,0.0074036404300424,0.0077013133478148,0.0086503177099892,0.0074261504312152,0.0064097419823486,0.0061727607246254,0.0061692066436121,0.0063166705333928,0.0069262749211103,0.0065662616865158,0.0059391873946114,0.0056784534597952,0.0055562392432827,0.005591946029164,0.0058365543110543,0.005960343554298,0.0059717056809413],"yaxis":"y","type":"scatter"},{"hovertemplate":"=construction<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"construction","line":{"color":"rgb(29, 105, 150)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"construction","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0063551101022307,0.0060646835508181,0.0056162438126854,0.005586981348693,0.005427017996334,0.005654163871231,0.0066085200134323,0.0065699880109325,0.0069316303418029,0.0067635493428425,0.0064457606147447,0.0067690020166692,0.0071646063455696,0.0067001123452691,0.0064386367011124,0.0062500096663862,0.0060583733372201,0.0058868501291467,0.0056302906911964,0.0054694425080872,0.005221566723034,0.0050319900247354],"yaxis":"y","type":"scatter"},{"hovertemplate":"=recourses<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"recourses","line":{"color":"rgb(56, 166, 165)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"recourses","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0061179028971187,0.0061043205454228,0.0065021902348052,0.0068951134222659,0.0068988249483463,0.006737129986269,0.0060205857137969,0.0054750295875024,0.0053462647849466,0.0056047944184784,0.0059520460894231,0.0054737798498561,0.0051316393458051,0.0048302759212979,0.0046528903363388,0.0048206727541906,0.0051690124190652,0.0054735805710693,0.0056920088313276,0.0061327414563209,0.0064482324232728,0.0068539297072175],"yaxis":"y","type":"scatter"},{"hovertemplate":"=tourism<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"tourism","line":{"color":"rgb(15, 133, 84)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"tourism","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0045540185166469,0.0047096499358689,0.0046753584767385,0.0041087121340152,0.0040876066219005,0.004067899755057,0.00369303225473,0.0032414002376553,0.0026605362438138,0.0023088908647381,0.0018460267777837,0.0017056540545605,0.0015406853085042,0.0014372555112745,0.001406379251808,0.0014131070429716,0.0014089320838568,0.0014005750576604,0.0014706284500128,0.0015155584219394,0 ...

# %%
# topic 6: agricultural expansion (2)
rows6 = ['clima', 'aquecimento_global', 'sustentável',
         'mudanças_climáticas',
         'natureza', 'meio_ambiente', 'efeito_estufa']

df6 = topic6.loc[topic6['words'].isin(rows6)]
df6 = pd.melt(df6, id_vars=["words"], var_name="year")

ae = px.line(df6,
             x="year",
             y="value",
             color='words',
             color_discrete_sequence=px.colors.qualitative.Prism,
             labels={"words":"", "value":"probability"},
             width=900, 
             height=700,
             #groupnorm='percent',
             title="Agricultural Expansion topic selected terms probability over time")

newnames = {"clima":"climate", "sustentável":"sustainable", "natureza":"nature", 
            "mudanças_climáticas":"climate change", "aquecimento_global":"global warming", "efeito_estufa":"greenhouse effect", 
            'meio_ambiente':'environment'}

ae.for_each_trace(lambda t: t.update(name = newnames[t.name],
                                     legendgroup = newnames[t.name],
                                     hovertemplate = t.hovertemplate.replace(t.name, newnames[t.name])
                                    ))

ae.update_layout(
    xaxis = dict(
        tickmode = 'array',
        tickvals = [2000, 2005, 2010, 2015, 2020]))

ae.write_html("/dtm_agricultural_expansion_2.html")
ae.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2b9c0928-0532-4361-87db-76828d2215ce" class="plotly-graph-div" style="height:700px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b9c0928-0532-4361-87db-76828d2215ce")) {                    Plotly.newPlot(                        "2b9c0928-0532-4361-87db-76828d2215ce",                        [{"hovertemplate":"=climate<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"climate","line":{"color":"rgb(95, 70, 144)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"climate","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0007763862170727,0.0007553374421949,0.0007425066950458,0.0007453743206142,0.0007836235333189,0.0008365647735726,0.000908471452928,0.0009890777728955,0.0010355834358805,0.0011507983731508,0.0012551098838614,0.0012562187582596,0.0012273637748264,0.0012444559817168,0.0012982672651065,0.0013950588538356,0.0014755246476827,0.0015626218822809,0.001614397861964,0.0016191882933159,0.0016687991628228,0.0017221694630471],"yaxis":"y","type":"scatter"},{"hovertemplate":"=environment<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"environment","line":{"color":"rgb(29, 105, 150)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"environment","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0006163180840181,0.0006208344253731,0.0006486177850779,0.0006949577948884,0.0007321344639259,0.0007719678476633,0.0008234801683119,0.0008663279187343,0.0008766477242619,0.0008508412554056,0.000814187244184,0.0007788760221216,0.0007543028025312,0.0007268335005425,0.0007269094726735,0.0007251121967319,0.0007315810220535,0.0007416895134207,0.0007511607329532,0.0007594610469168,0.0007522462404043,0.0007510146491865],"yaxis":"y","type":"scatter"},{"hovertemplate":"=sustainable<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"sustainable","line":{"color":"rgb(56, 166, 165)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"sustainable","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0005497919503657,0.000556093126757,0.0005687700461291,0.0005985160755895,0.0006237301402857,0.000648373438684,0.0006967382272631,0.0007549362618319,0.0008046633469586,0.0008325954271928,0.0008574788443006,0.0008838054114029,0.0009155961530409,0.0009486980533344,0.0010223406978668,0.0010788743018947,0.0011261505825512,0.0011693413235936,0.0011829827341086,0.0012051539851744,0.0012273512823773,0.0012237683677412],"yaxis":"y","type":"scatter"},{"hovertemplate":"=nature<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"nature","line":{"color":"rgb(15, 133, 84)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"nature","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.
# %%
# topic 9: national sovereignty
rows9 = ['defesa', 'exército', 'forças_armadas', 'território', 
         'fronteiras', 'drogas', 'violência', 'guerra',
         'vigilância']

df9 = topic9.loc[topic9['words'].isin(rows9)]
df9 = pd.melt(df9, id_vars=["words"], var_name="year")

ns = px.line(df9,
              x="year",
              y="value",
              color='words',
              color_discrete_sequence=px.colors.qualitative.Prism,
              labels={"words":"", "value":"probability"},
              width=900, 
              height=700,
              #groupnorm='percent',
              title="National Sovereignty topic selected terms probability over time")

newnames = {"defesa":"defence", "exército":"army", "forças_armadas":"military", 
            "violência":"violence", "território":"territory", "fronteiras":"borders",
            "drogas":"drugs", "guerra":"war", "vigilância":"surveillance"
           }

ns.for_each_trace(lambda t: t.update(name = newnames[t.name],
                                     legendgroup = newnames[t.name],
                                     hovertemplate = t.hovertemplate.replace(t.name, newnames[t.name])
                                    ))

ns.update_layout(
    xaxis = dict(
        tickmode = 'array',
        tickvals = [2000, 2005, 2010, 2015, 2020]))

ns.write_html("/dtm_national_sovereignty.html")
ns.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8381b25b-1039-459b-be08-935110ee0713" class="plotly-graph-div" style="height:700px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8381b25b-1039-459b-be08-935110ee0713")) {                    Plotly.newPlot(                        "8381b25b-1039-459b-be08-935110ee0713",                        [{"hovertemplate":"=defence<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"defence","line":{"color":"rgb(95, 70, 144)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"defence","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0081129754576305,0.0070537893479759,0.0066965158048067,0.0068703758954232,0.0073693646912798,0.0068184486784102,0.0071579327677373,0.0080001535873403,0.0082324662625695,0.0089330138433721,0.0078920931459958,0.0079410481777786,0.0101048057152996,0.0099269765590366,0.0117249365342766,0.0112091052997367,0.0109164334136407,0.01039660575736,0.0092570079820197,0.0076864099321973,0.0069073609612745,0.006582910878673],"yaxis":"y","type":"scatter"},{"hovertemplate":"=army<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"army","line":{"color":"rgb(29, 105, 150)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"army","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.005974048468826,0.0061340437785774,0.0066108416319224,0.0058999647490053,0.0061819817106168,0.0062177051763684,0.0066589421826055,0.0058248088253093,0.0056378046017014,0.0051795306727471,0.0048709665997259,0.0046418722521202,0.0045524897799234,0.0044443778983402,0.0046277519377447,0.0049873097565463,0.0050931440990573,0.0053346559080582,0.0047749952427155,0.0047507067236943,0.004345536268891,0.0041456066563503],"yaxis":"y","type":"scatter"},{"hovertemplate":"=military<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"military","line":{"color":"rgb(56, 166, 165)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"military","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.004566210132271,0.00416754200461,0.0038869529009412,0.0036021704177779,0.0036908724235044,0.0034970653359099,0.0038461414763573,0.0045084565029444,0.0051661044384368,0.0045327535152361,0.0037514834453311,0.0033890668651872,0.0034550885723662,0.0037861828271435,0.0043162829611665,0.0039185714534232,0.0036134951915142,0.0035511448456643,0.0036292650934879,0.0039559163784952,0.0038674829897587,0.0038397831108975],"yaxis":"y","type":"scatter"},{"hovertemplate":"=territory<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"territory","line":{"color":"rgb(15, 133, 84)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"territory","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0034928970039587,0.0032838388018389,0.0031514478891615,0.0028520658826227,0.0025885066137887,0.0023004518524602,0.0022082747108718,0.0020480072315715,0.002066417773196,0.0019118570996559,0.0018209959814883,0.001758177632396,0.0016500894329185,0.0015221350868308,0.0014406806156212,0.0013782942696456,0.0013105746551779,0.0012512084843161,0.0012123675682968,0.0011693699235699,0.0011540005909768,0.001136781470 ...

# %%
# topic 10: land rights
rows10 = ['terra', 'incra', 'reforma_agrária', 'assentamentos', 'reserva', 'produtor', 'regularização_fundiária',
          'rural', 'campo', 'empresa']

df10 = topic10.loc[topic10['words'].isin(rows10)]
df10 = pd.melt(df10, id_vars=["words"], var_name="year")

lr = px.line(df10,
              x="year",
              y="value",
              color='words',
              color_discrete_sequence=px.colors.qualitative.Prism,
              labels={"words":"", "value":"probability"},
              width=900, 
              height=700,
              #groupnorm='percent',
              title="Land Rights topic selected terms probability over time")

newnames = {"terra":"land", "incra":"incra", "reforma_agrária":"agrarian reform", 
            "assentamentos":"settlements", "reserva":"reserve", 
            "rural":"rural", "campo":"farm", "produtor":"producers", 
            "regularização_fundiária":"land regularization", "empresa":"company"
           }

lr.for_each_trace(lambda t: t.update(name = newnames[t.name],
                                     legendgroup = newnames[t.name],
                                     hovertemplate = t.hovertemplate.replace(t.name, newnames[t.name])
                                    ))

lr.update_layout(
    xaxis = dict(
        tickmode = 'array',
        tickvals = [2000, 2005, 2010, 2015, 2020]))

lr.write_html("/dtm_land_rights.html")
lr.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="03e27373-7ccb-4a9d-a345-1fef553fe773" class="plotly-graph-div" style="height:700px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03e27373-7ccb-4a9d-a345-1fef553fe773")) {                    Plotly.newPlot(                        "03e27373-7ccb-4a9d-a345-1fef553fe773",                        [{"hovertemplate":"=land<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"land","line":{"color":"rgb(95, 70, 144)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"land","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0102892328545408,0.01032822997283,0.0104285523312646,0.0112236664095568,0.0104581035448976,0.0100450072530167,0.008485061289869,0.0076847348424647,0.0076273326700756,0.0078177850455027,0.0066850805494304,0.0064206024935573,0.0064082653741681,0.0064648512152126,0.0063656608140148,0.0069303807590382,0.0082144176560097,0.0094514491816562,0.0095444998081973,0.0102403101771174,0.0119427441749185,0.0122543565258899],"yaxis":"y","type":"scatter"},{"hovertemplate":"=incra<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"incra","line":{"color":"rgb(29, 105, 150)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"incra","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.006531658257673,0.0067777770646117,0.0076787584215383,0.0085904589658798,0.0074116046589478,0.0087989656575945,0.0071166735575675,0.006412103623873,0.0055421079034368,0.0047558379775817,0.0043613556233651,0.0040829344536103,0.0043253303632306,0.004315658408282,0.0040187957703632,0.0043202986737308,0.0049320949036378,0.0053215765283278,0.0050358155993724,0.0048639642792863,0.0052679908945063,0.0053441373469868],"yaxis":"y","type":"scatter"},{"hovertemplate":"=agrarian reform<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"agrarian reform","line":{"color":"rgb(56, 166, 165)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"agrarian reform","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0061056282821198,0.0062839032600105,0.00673894088046,0.0062457437807874,0.0050107627562997,0.0043703567321569,0.0038284891443452,0.0036157529760478,0.0030648476194492,0.0029966210487604,0.0029700296565721,0.0031684610751644,0.0033161702259949,0.0033460221818106,0.003602588404828,0.0040036292435776,0.0047360954921485,0.0049634292235501,0.0043185804014398,0.004033084210159,0.0040677945632927,0.0039417764357971],"yaxis":"y","type":"scatter"},{"hovertemplate":"=farm<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"farm","line":{"color":"rgb(15, 133, 84)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"farm","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0032591703807416,0.0031556993435319,0.0033242611344561,0.0032832535201747,0.0030101818740358,0.0028688505405297,0.0025454396608029,0.0022474658740304,0.0021707215895927,0.0022547783669784,0.0023042287926201,0.0023588405040432,0.0023027370805449,0.0022686234471571,0.0023109142929504,0.0024454393921469,0.0024389913212902,0.0023737241657186,0.0023189116282001,0.0023054974945738,0.0023664051493347,0.002343431335 ...

# %%
# topic 11: environmental protection
rows11 = ['desenvolvimento', 'sustentável', 'preservação', 'desmatamento',
          'proteção', 'conservação', 'destruição',
          'queimadas', 'código_florestal', 'meio_ambiente']

df11 = topic11.loc[topic11['words'].isin(rows11)]
df11 = pd.melt(df11, id_vars=["words"], var_name="year")

ep = px.line(df11,
              x="year",
              y="value",
              color='words',
              color_discrete_sequence=px.colors.qualitative.Prism,
              labels={"words":"", "value":"probability"},
              width=900, 
              height=700,
              #groupnorm='percent',
              title="Environmental protection selected terms probability over time"
            )

newnames = {'desenvolvimento':'development', 'sustentável':'sustainable', 
            'preservação':'preservation', 'desmatamento':'deforestation',
            'proteção':'protection', 'conservação':'conservation', 'meio_ambiente':'environment', 
            'destruição':'destruction', 'queimadas':'fires', 'código_florestal':'forest code'
           }

ep.for_each_trace(lambda t: t.update(name = newnames[t.name],
                                     legendgroup = newnames[t.name],
                                     hovertemplate = t.hovertemplate.replace(t.name, newnames[t.name])
                                    ))


ep.update_layout(
    xaxis = dict(
        tickmode = 'array',
        tickvals = [2000, 2005, 2010, 2015, 2020]))

ep.write_html("/dtm_environmental_protection.html")
ep.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="cd93731d-1235-4f30-a98b-1ae120da3495" class="plotly-graph-div" style="height:700px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd93731d-1235-4f30-a98b-1ae120da3495")) {                    Plotly.newPlot(                        "cd93731d-1235-4f30-a98b-1ae120da3495",                        [{"hovertemplate":"=environment<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"environment","line":{"color":"rgb(95, 70, 144)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"environment","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0117471707018661,0.0122447935174675,0.0123556089437809,0.0125554297942186,0.0130713517176941,0.0134799023208595,0.0148318654142046,0.0139432348768249,0.0160138316219709,0.0168569483768798,0.0153874745597267,0.0123032839252836,0.0128917528642264,0.0176077876708367,0.0166258878933553,0.0144858680076837,0.014664987499416,0.0151542563244145,0.0202111935833231,0.023447943759709,0.0222338438795995,0.0217383829963557],"yaxis":"y","type":"scatter"},{"hovertemplate":"=development<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"development","line":{"color":"rgb(29, 105, 150)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"development","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0116515253555761,0.011643461551206,0.0129728446620047,0.0141568948342231,0.0130825055926069,0.012192342016453,0.0118211002509424,0.0113672618416895,0.0099374174309387,0.0089900942232868,0.0075141142178416,0.0065958280096709,0.0074225536630363,0.007511615794247,0.0069395973341124,0.0064457411325075,0.0055651268183136,0.004854462321023,0.0046660700303574,0.0045559339304661,0.0041942176494549,0.0040716300848774],"yaxis":"y","type":"scatter"},{"hovertemplate":"=sustainable<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"sustainable","line":{"color":"rgb(56, 166, 165)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"sustainable","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0056669545889086,0.0062707210779289,0.0074581469241526,0.0087624013290985,0.0084378961841606,0.0085690493727209,0.0086524497833453,0.0083772896401438,0.0077264153861314,0.0073262812829074,0.0063003850762045,0.0055113378072443,0.0060360729646237,0.0055242204622088,0.0052030073420673,0.0048687365170695,0.0043817138256785,0.0040513148839076,0.0038299025418929,0.0036581543042974,0.0035902613339228,0.0036235421829871],"yaxis":"y","type":"scatter"},{"hovertemplate":"=preservation<br>year=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"preservation","line":{"color":"rgb(15, 133, 84)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"preservation","orientation":"v","showlegend":true,"x":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[0.0043165248316065,0.0043428680327743,0.004176476737456,0.0038642433011272,0.0042118533896371,0.0044277087543949,0.0051427289594665,0.0059507471785856,0.0059366046177002,0.0064380196704105,0.0057124319015964,0.0055019020419173,0.0054295363531687,0.0060717080567363,0.0053332806185608,0.0048461481122787,0.0048690079718955,0.004918915511164,0.004814057526876, ...
