# %% [markdown]
# This notebook will scrape the links of the individual parliament discourses and save them in a new column, according to their respective speaker.

# %%
from bs4 import BeautifulSoup
import pandas as pd
import re
import requests
import time
from time import sleep
from urllib.request import urlopen
from urllib.error import HTTPError
from tqdm import tqdm, notebook

# %%
tqdm().pandas()

# %%
df = pd.read_csv('/congress_2021.tsv', sep='\t')

# %% [markdown]
# We will continue to employ the GitHub of the newspaper <a href="https://github.com/estadao/bolsonaro-e-ditadura-no-congresso/tree/master/code">O Estado de S.Paulo</a>. However, the discourses' text contents were initially extracted and saved in .txt format. We will add them to a new column of our data frame in this notebook.

# %%
def make_request(url):
    '''Takes an url, makes a get request request and returns a text string.'''
    try:
        headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36'}
        r = requests.get(url, headers=headers)
        r.encoding = 'utf-8'
        time.sleep(2)
    
    # if its a HTTP error, return its type
    except HTTPError as e:
        return e.response.status_code
    
    return r.text

# %%
def make_soup(data):  
    '''Takes a text string and returns a BeautifulSoup object. '''
    data = data.replace("<b>","").replace("</b>","") # need to remove </b> tags because the Chamber's developer put them out of order and this makes the scraper goes crazy
    soup = BeautifulSoup(data, 'html.parser') 
    return soup

# %%
def scrape_content(soup):
    
    '''
    Use BeautifulSoup to extract the content of the URL in which the speech is. 
    Returns a text string.
    
    In some cases there're broken links, unfortunately, we need to skip those
    errors otherwise the scraper wouldn't work out. Usually, the scraper finds error 
    as an attribute in the "find_all" method, however we found this is actually a 
    "504 Gateway Time-out" error. In any case, we print it.
    '''
    
    try:
        paragraph = soup.find("p", attrs = {"align":"justify"})
        
    # This extra step is necessary because in some cases there is more than one 'font' tag inside 
    # the 'p'. On these occasions, part of the text wasn't returned
        fonts = paragraph.find_all("font")
        text = [ font.text.strip() for font in fonts ]
        text = ' '.join(text)
        
    # if its an Attribute error, return its type
    except AttributeError as e:
        return e
    
    return text

# %%
def scrape_row(row):
    
    '''
    Execute via df.apply(): accesses the data from each row of the dataframe 
    and performs the necessary operations to access it. 
    '''

    if row.discourse_link:
            url = row.discourse_link
            data = make_request(url)
            soup = make_soup(data)
            txt = scrape_content(soup)
    return txt

# %%
# foi pela marilene que consegui fazer o código funcionar hoje (22/09)!
df['original_discourse'] = df.progress_apply(scrape_row, axis=1)
# Out:
# 100%|█████████████████████████████████| 20654/20654 [18:40:45<00:00,  3.26s/it]

# %%
df
# Out:
#             date     session   phase  \
# 0     2021-12-21   35.2021.N  agenda
# 1     2021-12-21   35.2021.N  agenda
# 2     2021-12-21   35.2021.N  agenda
# 3     2021-12-21   35.2021.N  agenda
# 4     2021-12-21   35.2021.N  agenda
# ...          ...         ...     ...
# 20649 2021-09-27  017.3.56.N  agenda
# 20650 2021-09-27  017.3.56.N  agenda
# 20651 2021-09-27  017.3.56.N  agenda
# 20652 2021-07-15  015.3.56.N  agenda
# 20653 2021-12-17  034.3.56.N  agenda
#
#                                           discourse_link  \
# 0      https://www.camara.leg.br/internet/sitaqweb/Te...
# 1      https://www.camara.leg.br/internet/sitaqweb/Te...
# 2      https://www.camara.leg.br/internet/sitaqweb/Te...
# 3      https://www.camara.leg.br/internet/sitaqweb/Te...
# 4      https://www.camara.leg.br/internet/sitaqweb/Te...
# ...                                                  ...
# 20649  https://www.camara.leg.br/internet/sitaqweb/Te...
# 20650  https://www.camara.leg.br/internet/sitaqweb/Te...
# 20651  https://www.camara.leg.br/internet/sitaqweb/Te...
# 20652  https://www.camara.leg.br/internet/sitaqweb/Te...
# 20653  https://www.camara.leg.br/internet/sitaqweb/Te...
#
#                         speaker  party  coalition state     region  \
# 0                     hugo leal    psd          0    rj  southeast
# 1                domingos sávio   psdb          0    mg  southeast
# 2               moses rodrigues    mdb          0    ce  northeast
# 3            dra. soraya manato    psl          0    es  southeast
# 4      delegado marcelo freitas    psl          0    mg  southeast
# ...                         ...    ...        ...   ...        ...
# 20649          perpétua almeida  pcdob          0    ac      north
# 20650            marcelo freixo   psol          0    rj  southeast
# 20651         arlindo chinaglia     pt          0    sp  southeast
# 20652           juscelino filho    dem          0    ma  northeast
# 20653             marcelo ramos     pl          0    am      north
#
#                                       original_discourse
# 0      O SR. HUGO LEAL (PSD - RJ. Como Relator. Sem r...
# 1      O SR. DOMINGOS SÁVIO (PSDB - MG. Pela ordem. S...
# 2      O SR. MOSES RODRIGUES (MDB - CE. Pela ordem. S...
# 3      A SRA. DRA. SORAYA MANATO (PSL - ES. Pela orde...
# 4      O SR. DELEGADO MARCELO FREITAS (PSL - MG. Pela...
# ...                                                  ...
# 20649  A SRA. PERPÉTUA ALMEIDA (Bloco/PCdoB - AC. Par...
# 20650  O SR. MARCELO FREIXO (Bloco/PSB - RJ. Para dis...
# 20651  O SR. ARLINDO CHINAGLIA (Bloco/PT - SP. Para d...
# 20652  O SR. JUSCELINO FILHO (DEM - MA. Como Relator....
# 20653  O SR. PRESIDENTE (Marcelo Ramos. PL - AM. Para...
#
# [20654 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20654 entries, 0 to 20653
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                20654 non-null  object
#  1   session             20654 non-null  object
#  2   phase               20654 non-null  object
#  3   discourse_link      20654 non-null  object
#  4   speaker             20654 non-null  object
#  5   party               20654 non-null  object
#  6   coalition           20654 non-null  int64
#  7   state               20654 non-null  object
#  8   region              20654 non-null  object
#  9   original_discourse  20654 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.6+ MB

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y/%m/%d')

# %%
# checking potential scraping errors in the discourse column
df[df["original_discourse"].str.contains("NoneType", na=False)]
# Out:
# Empty DataFrame
# Columns: [date, session, phase, discourse_link, speaker, party, coalition, state, region, original_discourse]
# Index: []

# %%
# checking null entries
df[df['original_discourse'].isnull()]
# Out:
# Empty DataFrame
# Columns: [date, session, phase, discourse_link, speaker, party, coalition, state, region, original_discourse]
# Index: []

# %% [markdown]
# We need to check manually the entries in which the scraper didn't work, link by link. Some links hold blanked pages, the ones with content were then manually inserted into the data frame.

# %%
# checking potential duplicates
pd.concat(g for _, g in df.groupby('original_discourse') if len(g) > 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda\lib\site-packages\pandas\core\algorithms.py in safe_sort(values, codes, na_sentinel, assume_unique, verify)
#    2014         try:
# -> 2015             sorter = values.argsort()
#    2016             ordered = values.take(sorter)
#
# TypeError: '<' not supported between instances of 'AttributeError' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-3ede56afabce> in <module>
#       1 # checking potential discourses duplicates
# ----> 2 pd.concat(g for _, g in df.groupby('original_discourse') if len(g) > 1)
#
# C:\ProgramData\Anaconda\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     269     ValueError: Indexes have overlapping values: ['a']
#     270     """
# --> 271     op = _Concatenator(
#     272         objs,
#     273         axis=axis,
#
# C:\ProgramData\Anaconda\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     324             objs = [objs[k] for k in keys]
#     325         else:
# --> 326             objs = list(objs)
#     327
#     328         if len(objs) == 0:
#
# <ipython-input-17-3ede56afabce> in <genexpr>(.0)
#       1 # checking potential discourses duplicates
# ----> 2 pd.concat(g for _, g in df.groupby('original_discourse') if len(g) > 1)
#
# C:\ProgramData\Anaconda\lib\site-packages\pandas\core\groupby\ops.py in get_iterator(self, data, axis)
#     122         for each group
#     123         """
# --> 124         splitter = self._get_splitter(data, axis=axis)
#     125         keys = self._get_group_keys()
#     126         for key, (i, group) in zip(keys, splitter):
#
# C:\ProgramData\Anaconda\lib\site-packages\pandas\core\groupby\ops.py in _get_splitter(self, data, axis)
#     128
#     129     def _get_splitter(self, data: FrameOrSeries, axis: int = 0) -> "DataSplitter":
# --> 130         comp_ids, _, ngroups = self.group_info
#     131         return get_splitter(data, comp_ids, ngroups, axis=axis)
#     132
#
# pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# C:\ProgramData\Anaconda\lib\site-packages\pandas\core\groupby\ops.py in group_info(self)
#     262     @cache_readonly
#     263     def group_info(self):
# --> 264         comp_ids, obs_group_ids = self._get_compressed_codes()
#     265
#     266         ngroups = len(obs_group_ids)
#
# C:\ProgramData\Anaconda\lib\site-packages\pandas\core\groupby\ops.py in _get_compressed_codes(self)
#     278
#     279     def _get_compressed_codes(self) -> Tuple[np.ndarray, np.ndarray]:
# --> 280         all_codes = self.codes
#     281         if len(all_codes) > 1:
#     282             group_index = get_group_index(all_codes, self.shape, sort=True, xnull=True)
#
# C:\ProgramData\Anaconda\lib\site-packages\pandas\core\groupby\ops.py in codes(self)
#     223     @property
#     224     def codes(self) -> List[np.ndarray]:
# --> 225         return [ping.codes for ping in self.groupings]
#     226
#     227     @property
#
# C:\ProgramData\Anaconda\lib\site-packages\pandas\core\groupby\ops.py in <listcomp>(.0)
#     223     @property
#     224     def codes(self) -> List[np.ndarray]:
# --> 225         return [ping.codes for ping in self.groupings]
#     226
#     227     @property
#
# C:\ProgramData\Anaconda\lib\site-packages\pandas\core\groupby\grouper.py in codes(self)
#     391     def codes(self) -> np.ndarray:
#     392         if self._codes is None:
# --> 393             self._make_codes()
#     394         return self._codes
#     395
#
# C:\ProgramData\Anaconda\lib\site-packages\pandas\core\groupby\grouper.py in _make_codes(self)
#     414                 uniques = self.grouper.result_index
#     415             else:
# --> 416                 codes, uniques = algorithms.factorize(self.grouper, sort=self.sort)
#     417                 uniques = Index(uniques, name=self.name)
#     418             self._codes = codes
#
# C:\ProgramData\Anaconda\lib\site-packages\pandas\core\algorithms.py in factorize(values, sort, na_sentinel, size_hint)
#     638
#     639     if sort and len(uniques) > 0:
# --> 640         uniques, codes = safe_sort(
#     641             uniques, codes, na_sentinel=na_sentinel, assume_unique=True, verify=False
#     642         )
#
# C:\ProgramData\Anaconda\lib\site-packages\pandas\core\algorithms.py in safe_sort(values, codes, na_sentinel, assume_unique, verify)
#    2017         except TypeError:
#    2018             # try this anyway
# -> 2019             ordered = sort_mixed(values)
#    2020
#    2021     # codes:
#
# C:\ProgramData\Anaconda\lib\site-packages\pandas\core\algorithms.py in sort_mixed(values)
#    2000         # order ints before strings, safe in py3
#    2001         str_pos = np.array([isinstance(x, str) for x in values], dtype=bool)
# -> 2002         nums = np.sort(values[~str_pos])
#    2003         strs = np.sort(values[str_pos])
#    2004         return np.concatenate([nums, np.asarray(strs, dtype=object)])
#
# <__array_function__ internals> in sort(*args, **kwargs)
#
# ~\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py in sort(a, axis, kind, order)
#     989     else:
#     990         a = asanyarray(a).copy(order="K")
# --> 991     a.sort(axis=axis, kind=kind, order=order)
#     992     return a
#     993
#
# TypeError: '<' not supported between instances of 'AttributeError' and 'AttributeError'

# %%
# some discourses have carriage return (\r), new line (\n), tab (\t), and \xa0. Let's clean it up:
df["original_discourse"] = df["original_discourse"].str.replace(r"\r+|\n+|\t+", " ", regex=True).str.split().str.join(" ")

# %%
df.to_csv('congress_speeches_2021.tsv', sep='\t', index=False)
